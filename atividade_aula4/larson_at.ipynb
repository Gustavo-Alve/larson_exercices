# %% [markdown]
# # Atividades Aula de estatistica

# %% [markdown]
# ## Importando minhas bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista_numerica = [128, 100, 180, 150, 200, 90, 340, 105, 85, 270,
    200, 65, 230, 150, 150, 120, 130, 80, 230, 200,
    110, 126, 170, 132, 140, 112, 90, 340, 170, 190]

df = pd.DataFrame(lista_numerica, columns=['Dados'])

minimo = min(df['Dados']) #65
maximo = max(df['Dados']) #340
amplitude = (maximo - minimo) #275
mediana= df['Dados'].median() #145.0
moda = df['Dados'].mode() # 150 - 200
media = df['Dados'].mean() # 159.44
classes = pd.cut(lista_numerica, bins=([65, 105, 145, 185, 225, 265, 305, 345])) #esse numero de bins serve para separar minhas classes de onde começam e onde terminam
frequencia = classes.value_counts()
total_frequencia  = frequencia.sum() # 30 porem no meu codigo esta dando 29 pois ele pega a primeira classe como 65-105 e assim por diante
intervalos = classes.categories
ponto_medio = (intervalos[0].left + intervalos[0].right - 1)/2 # apos Calcular o primeiro ponto medio  e apenas somar mais intervalo de classes que e 40 nesse caso
frequencia_relativa = frequencia/30 # A frequencia relativa e minha frequencia dividida pelo total dela que no exercicio e 30, faça isso para todas as frequencias
# print(frequencia_relativa.round(2)) #round usado para pegar apenas dois valores apos a virgula
frequencia_acumulada = frequencia.cumsum() #cumsum() funçao usada para calcular frequencia acumulada. os valores estao um pouco divergentes devido aquele problema das classes
# print(ponto_medio)

# %% [markdown]
# ## Resultado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Construindo um Histograma de frequência

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fronteira = (intervalos[0].left-0.5), (intervalos[1].right +0.5) # 64,5 - 104,5
 # Calculando os intervalos da primeira classe,apos isso basta apenas somar pelo tamanho da classe que no exercicio e 40
lista_intervalos = [64.5,104.5,144.5,184.5,224.5,264.5,304.5]

plt.bar(lista_intervalos,frequencia.values,width=40, edgecolor='black', color='Orange')
plt.title('Histograma')
plt.xlabel('Intervalos')
plt.ylabel('frequencia')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista_pontos_medios = [84.5,124.5,164.5,204.5,244.5,284.5,324.5]
plt.bar(lista_pontos_medios, frequencia.values, width=40, edgecolor = 'black', color = 'green')
plt.title('Histograma Pontos Medios')
plt.xlabel('Pontos Medios')
plt.ylabel('frequencia')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot(lista_pontos_medios, frequencia.values, '-o', color='Purple')
plt.title('Polígno de Frequencia')
plt.xlabel('Pontos médios')
plt.ylabel('Frequencia')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot(lista_pontos_medios, frequencia_acumulada, 'o-', color='blue')
plt.title('Ogiva')
plt.xlabel('Pontos médios')
plt.ylabel('Frequencia')
plt.show()

# %% [markdown]
# # Atividade 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista_numerica_2 = [91,472,279,249,530,376,188,341,266,199,
                    142,273,189,130,489,266,248,101,375,486,
                    190,398,188,269,43,30,127,354,84]

df_2 = pd.DataFrame(lista_numerica_2, columns=['Dados'])


minimo_2 = min(df_2['Dados']) #30
maximo_2 = max(df_2['Dados']) #530
amplitude_2 = (maximo_2 - minimo_2) #500
media_2 = df_2['Dados'].mean() #254.24
moda_2 = df_2['Dados'].mode() # 188 - 266
mediana_2 = df_2['Dados'].median() #249
classes_2 = pd.cut(lista_numerica_2, bins=([30,114,198,282,366,450,534])) #para se definir o tamano das classes podemos usar o metodo de STURGES 
#depois para ccalcular o tamanho fazemos tampanho = amplitude / numero de classes
frequencia_2 = classes_2.value_counts()
total_frequencia_2 = frequencia_2.sum() #28
intervalos_2 = classes_2.categories
frequencia_relativa_2 = frequencia_2/28
frequencia_acumulada_2 = frequencia_2.cumsum()
ponto_medio_2 = (intervalos_2[0].left + intervalos_2[0].right)/2
# print(media_2)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
fronteira_2 = (intervalos_2[0].left-0.5), (intervalos_2[1].right +0.5) 
lista_intervalos_2 = [29.5,113.5,197.5,281.5,365.5,449.5]
# print(fronteira_2)

plt.bar(lista_intervalos_2,frequencia_2.values,width=40, edgecolor='black', color='Orange')

plt.bar(lista_intervalos_2, frequencia_2.values, width=40,edgecolor ='Black', color= 'Purple')
plt.title('Histograma')
plt.xlabel('Intervalos')
plt.ylabel('frequencia')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista_pontos_medios_2 = [72,156,240,324,408,492]

plt.plot(lista_pontos_medios_2, frequencia_2.values, '-o', color='Red')
plt.title('Polígno de Frequência')
plt.xlabel('Pontos Medios')
plt.ylabel('Frequencia Acumulada')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot(lista_pontos_medios_2, frequencia_acumulada_2, '-o', color='orange')
plt.title('Ogiva')
plt.xlabel('Pontos Medios')
plt.ylabel('Frequencia Acumulada')
plt.show()
