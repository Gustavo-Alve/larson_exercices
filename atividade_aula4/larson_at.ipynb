# %% [markdown]
# # Atividades Aula de estatistica

# %% [markdown]
# ## Importando minhas bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista_numerica = [128,100,180,150,200,200,340,105,85,270,200,65,
    230,150,150,120,130,80,230,200,
    110,126,170,132,140,112,90,340,170,190]

df = pd.DataFrame(lista_numerica, columns=['Dados'])

minimo = min(df['Dados'])
maximo = max(df['Dados'])
amplitude = (maximo - minimo)
media= df['Dados'].median()
moda = df['Dados'].mode()
print(moda)
# Out:
# 0    200
# Name: Dados, dtype: int64
